# %% [markdown]
# # Creating Alerts with Reconstruction Errors and Anomaly Scores:

# %% [markdown]
# ### Imports & Constants:

# %%
import os
import config
import numpy as np
import pandas as pd
from config import RECON_TABLE_PATH, UEBA_PATH, SCORES_PATH
from scripts.AlertObjectBuilder import *

# %%
SAVE_PATH = f"alert_table_{config.MODEL_VERSION}.parquet"
AGG_CASE_PATH = f"cases_{config.MODEL_VERSION}.parquet"

# %% [markdown]
# ### Loading Reconstruction Error and Anomaly Score Data:

# %%
# Loading reconstruction table
reconstruction_error_table = pd.read_parquet(RECON_TABLE_PATH)

# %%
# Loading anomaly scores and temporal context columns (z-scores, rolling deltas)
ueba_dataset = pd.read_parquet(UEBA_PATH)

# Drop accidental index columns created during prior exports
index_like_cols = [
    col for col in ueba_dataset.columns
    if col.lower() in {"unnamed: 0", "index", "level_0"}
       or col.lower().startswith("unnamed:")
]
if index_like_cols:
    ueba_dataset = ueba_dataset.drop(columns=index_like_cols)
anomaly_scores = np.load(SCORES_PATH)

# Include z-score and rolling-delta columns for explanation text
zscore_cols = [c for c in ueba_dataset.columns if c.endswith("_zscore")]
delta_cols = [c for c in ueba_dataset.columns if c.endswith("_rolling_delta")]
anomaly_score_table = ueba_dataset[["user", "day"] + zscore_cols + delta_cols].copy()
anomaly_score_table["day"] = pd.to_datetime(anomaly_score_table["day"]).dt.normalize()
anomaly_score_table["if_anomaly_score"] = anomaly_scores

# %%
# Joining reconstruction errors and anomaly scores
aggregated_table = reconstruction_error_table.merge(anomaly_score_table, on=["user", "day"], how="left")

# %% [markdown]
# ### Initializing and Creating Alert Table:

# %%
builder = AlertObjectBuilder(top_k=3)

# Ordering errors and scores to assign risk levels and percentiles
builder.fit_ae_baseline(aggregated_table["total_reconstruction_error"].values)
builder.fit_if_baseline(aggregated_table["if_anomaly_score"].values)

# %%
alert_df = builder.build_alert_df(aggregated_table, w1=0.5, w2=0.5)

# %%
alert_df.head()
# Out:
#       user        day  ae_percentile_rank ae_risk_band  \
# 0  ama2808 2010-01-02           71.111667          LOW
# 1  gne1365 2010-01-02           60.357089          LOW
# 2  jwm0484 2010-01-02           86.307484       MEDIUM
# 3  tkm1539 2010-01-02           99.822900     CRITICAL
# 4  akk2125 2010-01-02           52.124216          LOW
#
#                                     top_contributors  if_anomaly_score  \
# 0  [(http_total_requests, 0.1125316321849823), (e...          0.688707
# 1  [(http_long_url_count, 0.15945082902908325), (...          0.688687
# 2  [(http_download_count, 0.37084636092185974), (...          0.675289
# 3  [(off_hours_files_accessed, 0.6690912246704102...          0.690864
# 4  [(unique_domains_visited, 0.22456753253936768)...          0.687062
#
#    if_percentile_rank if_risk_band  composite_score composite_risk_band  \
# 0           99.340846     CRITICAL        85.226257              MEDIUM
# 1           99.338636     CRITICAL        79.847863                 LOW
# 2           99.029263     CRITICAL        92.668373                HIGH
# 3           99.408245     CRITICAL        99.615573            CRITICAL
# 4           99.213309     CRITICAL        75.668763                 LOW
#
#    both_signals_high                                        explanation
# 0              False  AE deviation at 71.1th pct (LOW); IF anomaly a...
# 1              False  AE deviation at 60.4th pct (LOW); IF anomaly a...
# 2              False  AE deviation at 86.3th pct (MEDIUM); IF anomal...
# 3               True  AE deviation at 99.8th pct (CRITICAL); IF anom...
# 4              False  AE deviation at 52.1th pct (LOW); IF anomaly a...

# %%
# Saving alert table
save_table(df=alert_df, save_path=SAVE_PATH)
# Out:
# Successfully saved to: explainability\alert_table\alert_table_5.parquet

# %% [markdown]
# ### Aggregating Alerts into Cases:

# %%
cases_df = builder.aggregate_alerts(alert_df, window_days=5, min_risk="HIGH")
cases_df.head(10)
# Out:
#       user case_start   case_end  anomalous_days  max_composite  \
# 0  acm2278 2010-08-04 2010-09-09              22      99.999921
# 1  sdh2394 2010-01-02 2011-04-11             444      99.997751
# 2  chb1062 2010-01-04 2011-04-11             322      99.995067
# 3  leb1764 2010-01-04 2011-04-11             323      99.994673
# 4  bmm0462 2010-01-04 2011-04-11             322      99.994515
# 5  dlm2440 2010-01-04 2011-04-11             322      99.994002
# 6  ikp1047 2010-01-04 2010-11-29             232      99.993726
# 7  cam3050 2010-01-04 2011-04-11             322      99.992739
# 8  qah0048 2010-01-04 2011-04-11             322      99.992463
# 9  kef1057 2010-01-04 2011-04-11             331      99.992108
#
#    mean_composite  peak_ae_percentile  peak_if_percentile  confirmed_days  \
# 0       98.873745           99.999921           99.999921              22
# 1       98.080977           99.996685           99.998816             438
# 2       99.493764           99.997080           99.999684             322
# 3       99.268311           99.994081           99.999605             322
# 4       99.192131           99.998579           99.996291             322
# 5       99.262835           99.998264           99.999369             322
# 6       99.308009           99.998422           99.998895             231
# 7       99.344935           99.997159           99.998895             322
# 8       99.334266           99.998500           99.999290             322
# 9       99.222464           99.998658           99.999211             331
#
#            trend case_risk_band
# 0     ESCALATING       CRITICAL
# 1  DE-ESCALATING       CRITICAL
# 2  DE-ESCALATING       CRITICAL
# 3     ESCALATING       CRITICAL
# 4     ESCALATING       CRITICAL
# 5     ESCALATING       CRITICAL
# 6  DE-ESCALATING       CRITICAL
# 7     ESCALATING       CRITICAL
# 8     ESCALATING       CRITICAL
# 9     ESCALATING       CRITICAL

# %%
save_table(cases_df, AGG_CASE_PATH)
# Out:
# Successfully saved to: explainability\alert_table\cases_5.parquet
