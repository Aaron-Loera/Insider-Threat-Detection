# %% [markdown]
# > **Documentation / analysis only.** The production path for this step is the headless pipeline:
# > `python -m ueba.pipeline calibrate / build-alerts --split main`
# >
# > This notebook is kept as the narrative record of the training procedure and for interactive
# > exploration. The pipeline stages call the same `ueba.*` package functions, validate their
# > input artifacts through a fail-fast manifest, and persist evaluation metrics as JSON.
# > See `docs/PIPELINE.md`.

# %% [markdown]
# # **Creating Alerts with Reconstruction Errors and Anomaly Scores**:

# %% [markdown]
# ### Imports & Constants:

# %%
import os
import json
import config
import joblib
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model as _load_keras_model
from config import (
    RECON_TABLE_PATH, UEBA_PATH, SCORES_PATH,
    UEBA_CALIBRATION_PATH, UEBA_CALIB_EVAL_PATH, SCALER_PATH, AE_PATH, ENCODER_PATH, IF_PATH,
    AE_BASELINE_PATH, IF_BASELINE_PATH, CALIBRATION_THRESHOLD_PATH, INSIDERS_PATH,
)
from prepare_data import get_insiders, to_model_matrix
from scripts.AlertObjectBuilder import *
from scripts.UEBAIsolationForest import UEBAIsolationForest

# %%
SAVE_PATH     = os.path.join(f"alert_table_{config.MODEL_VERSION}", f"alert_table_{config.MODEL_VERSION}.parquet")
AGG_CASE_PATH = os.path.join(f"alert_table_{config.MODEL_VERSION}", f"cases_{config.MODEL_VERSION}.parquet")

# %% [markdown]
# ### Loading Reconstruction Error and Anomaly Score Data:

# %%
# Loading reconstruction table
reconstruction_error_table = pd.read_parquet(RECON_TABLE_PATH)

# %%
# Loading anomaly scores and temporal context columns (z-scores, rolling deltas)
ueba_dataset = pd.read_parquet(UEBA_PATH)
ueba_dataset = ueba_dataset[ueba_dataset["baseline_complete"]].reset_index(drop=True)
anomaly_scores = np.load(SCORES_PATH)

# %%
# Include z-score and rolling-delta columns for explanation text
zscore_cols = [c for c in ueba_dataset.columns if c.endswith("_zscore")]
delta_cols = [c for c in ueba_dataset.columns if c.endswith("_rolling_delta")]

# %%
anomaly_score_table = ueba_dataset[["user", "day"] + zscore_cols + delta_cols].copy()
anomaly_score_table["day"] = pd.to_datetime(anomaly_score_table["day"]).dt.normalize()
anomaly_score_table["if_anomaly_score"] = anomaly_scores

# %%
# Joining reconstruction errors and anomaly scores.
# Inner-join so any future row-count drift between the two pipelines surfaces as a row loss
# rather than silently inflating CRITICAL bands through NaN-as-max searchsorted behavior.
aggregated_table = reconstruction_error_table.merge(anomaly_score_table, on=["user", "day"], how="inner")
assert len(aggregated_table) == len(reconstruction_error_table) == len(anomaly_score_table), \
    "Recon table and anomaly-score table must align after the baseline_complete filter"

# %% [markdown]
# ### Initializing and Creating Alert Table:

# %% [markdown]
# ### Building Clean Calibration Baseline and Calibrating Absolute Thresholds (Sprint 1 — Items 1 & 2):

# %%
# Load calibration slice and exclude ALL known insider users (not just in-window rows)
calib_df = pd.read_parquet(UEBA_CALIBRATION_PATH)
calib_df["day"] = pd.to_datetime(calib_df["day"]).dt.normalize()
calib_df["user"] = calib_df["user"].str.strip().str.lower()

insiders_df = get_insiders(path=INSIDERS_PATH, version=6.2)
insider_users = set(insiders_df["user"].str.strip().str.lower().unique())
calib_clean = calib_df[~calib_df["user"].isin(insider_users)].copy()
print(f"Calibration rows after insider exclusion: {len(calib_clean):,} / {len(calib_df):,}")
# Out:
# Calibration rows after insider exclusion: 135,356 / 135,356

# %%
# Score calibration rows through v{MODEL_VERSION} AE and IF
scaler = joblib.load(SCALER_PATH)
ae_model = _load_keras_model(AE_PATH, compile=False)
enc_model = _load_keras_model(ENCODER_PATH, compile=False)
iforest = UEBAIsolationForest()
iforest.load(IF_PATH)

# %%
x_calib, _ = to_model_matrix(calib_clean)
x_calib_scaled = scaler.transform(x_calib)

# %%
# AE total reconstruction error = SUM of squared errors per sample (matches reconstruction_error_table)
ae_reconstructed = ae_model.predict(x_calib_scaled, batch_size=4096)
ae_calib_errors = np.sum(np.square(x_calib_scaled - ae_reconstructed.astype("float32")), axis=1)

# IF anomaly scores on calibration embeddings
calib_embeddings = enc_model.predict(x_calib_scaled, batch_size=4096)
if_calib_scores = iforest.anomaly_score(calib_embeddings)

# Save clean baseline arrays alongside model artifacts
os.makedirs(os.path.dirname(AE_BASELINE_PATH), exist_ok=True)
os.makedirs(os.path.dirname(IF_BASELINE_PATH), exist_ok=True)
np.save(AE_BASELINE_PATH, ae_calib_errors)
np.save(IF_BASELINE_PATH, if_calib_scores)
print(f"Saved AE clean baseline : {len(ae_calib_errors):,} values  → {AE_BASELINE_PATH}")
print(f"Saved IF clean baseline : {len(if_calib_scores):,} values  → {IF_BASELINE_PATH}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Saved AE clean baseline : 135,356 values  → c:\Users\loera\Documents\Insider-Threat-Detection\encoders\encoder_model_6\ae_baseline_clean.npy
# Saved IF clean baseline : 135,356 values  → c:\Users\loera\Documents\Insider-Threat-Detection\isolation_forests\iforest_model_6\if_baseline_clean.npy

# %%
# Calibrate absolute thresholds against the clean calibration baseline.
# CRITICAL has no upper bound — represented as null in JSON, converted to float("inf") on load.
# Target budget: ~0.5% of clean user-days exceed HIGH; ~0.05% exceed CRITICAL
ae_thresholds = {
    "LOW":      float(np.percentile(ae_calib_errors, 95.0)),   # 5% of clean days exceed
    "MEDIUM":   float(np.percentile(ae_calib_errors, 99.0)),   # 1% exceed
    "HIGH":     float(np.percentile(ae_calib_errors, 99.5)),   # 0.5% exceed
    "CRITICAL": None,                                           # no upper bound
}
if_thresholds = {
    "LOW":      float(np.percentile(if_calib_scores, 95.0)),
    "MEDIUM":   float(np.percentile(if_calib_scores, 99.0)),
    "HIGH":     float(np.percentile(if_calib_scores, 99.5)),
    "CRITICAL": None,
}

with open(CALIBRATION_THRESHOLD_PATH, "w") as f:
    json.dump({"ae": ae_thresholds, "if": if_thresholds}, f, indent=2)

print("Calibrated absolute thresholds saved to:", CALIBRATION_THRESHOLD_PATH)
print(f"\nAE thresholds  — LOW: {ae_thresholds['LOW']:.2f}  MEDIUM: {ae_thresholds['MEDIUM']:.2f}  HIGH: {ae_thresholds['HIGH']:.2f}  CRITICAL: ∞")
print(f"IF thresholds  — LOW: {if_thresholds['LOW']:.4f}  MEDIUM: {if_thresholds['MEDIUM']:.4f}  HIGH: {if_thresholds['HIGH']:.4f}  CRITICAL: ∞")
# Out:
# Calibrated absolute thresholds saved to: c:\Users\loera\Documents\Insider-Threat-Detection\encoders\encoder_model_6\calibration_thresholds.json
#
# AE thresholds  — LOW: 241.75  MEDIUM: 543.52  HIGH: 741.59  CRITICAL: ∞
# IF thresholds  — LOW: 0.5540  MEDIUM: 0.6647  HIGH: 0.7074  CRITICAL: ∞

# %%
# Load calibrated absolute thresholds
with open(CALIBRATION_THRESHOLD_PATH) as f:
    _thresholds = json.load(f)

builder = AlertObjectBuilder(
    top_k=3,
    ae_absolute_thresholds=_thresholds["ae"],
    if_absolute_thresholds=_thresholds["if"],
)

# Fit baselines on the clean calibration distribution (not the full scored population)
builder.fit_ae_baseline(np.load(AE_BASELINE_PATH))
builder.fit_if_baseline(np.load(IF_BASELINE_PATH))

# %%
alert_df = builder.build_alert_df(aggregated_table, w1=0.5, w2=0.5)

# %%
alert_df.head()
# Out:
#       user        day  ae_percentile_rank ae_risk_band  \
# 0  kjs1940 2010-01-16           80.913295          LOW
# 1  nbt3447 2010-01-16           96.986465       MEDIUM
# 2  zar0404 2010-01-16           63.146813          LOW
# 3  hmb0805 2010-01-16           84.107095          LOW
# 4  adp3667 2010-01-16           98.956825       MEDIUM
#
#                                     top_contributors  if_anomaly_score  \
# 0  [(logon_count_zscore, 0.10348886996507645), (h...          0.338827
# 1  [(http_download_count_1d_over_30d_ratio, 0.259...          0.463955
# 2  [(unique_recipients_1d_over_30d_ratio, 0.24284...          0.350290
# 3  [(http_upload_count_zscore, 0.1572966873645782...          0.372079
# 4  [(logon_longest_active_run_minutes_zscore, 0.2...          0.465133
#
#    if_percentile_rank if_risk_band  composite_score composite_risk_band  \
# 0           58.872159          LOW        69.892727                 LOW
# ...

# %%
# Saving alert table
save_table(df=alert_df, save_path=SAVE_PATH)
# Out:
# Successfully saved to: explainability\alert_table\alert_table_6\alert_table_6.parquet

# %% [markdown]
# ### Aggregating Alerts into Cases:

# %%
cases_df = builder.aggregate_alerts(alert_df, window_days=5, min_risk="HIGH")
cases_df.head(10)
# Out:
#       user case_start   case_end  anomalous_days  max_composite  \
# 0  acm2278 2010-08-11 2010-09-09              19     100.000000
# 1  klp3864 2010-11-29 2010-12-22              16      99.999261
# 2  cag2442 2010-01-22 2011-02-18             273      99.997784
# 3  thh2751 2011-01-06 2011-02-18              32      99.997045
# 4  jcp1462 2010-01-18 2011-02-18             313      99.996306
# 5  chb1062 2010-01-22 2011-02-18             272      99.995937
# 6  klp3864 2010-09-08 2010-11-23              48      99.995937
# 7  djs1127 2010-01-20 2011-02-18             326      99.995198
# 8  bpd2437 2010-01-20 2011-02-19             315      99.994459
# 9  ref3266 2010-09-28 2010-10-07               8      99.992612
#
#    mean_composite  peak_ae_percentile  peak_if_percentile  confirmed_days  \
# 0       99.621660          100.000000          100.000000              18
# 1       96.636462           99.999261           99.999261               5
# ...

# %%
save_table(cases_df, AGG_CASE_PATH)
# Out:
# Successfully saved to: explainability\alert_table\alert_table_6\cases_6.parquet

# %% [markdown]
# ### Building Held-Out Test Stream Alert Table (Sprint 1 — Item 11):
# Note: Run `Reconstruction_Error_Explainer.ipynb` on the test stream first to generate the test reconstruction error table.

# %%
TEST_SAVE_PATH     = os.path.join(f"alert_table_{config.MODEL_VERSION}", f"alert_table_{config.MODEL_VERSION}_test.parquet")
TEST_AGG_CASE_PATH = os.path.join(f"alert_table_{config.MODEL_VERSION}", f"cases_{config.MODEL_VERSION}_test.parquet")

# Expected path for test reconstruction error table (produced by Reconstruction_Error_Explainer.ipynb)
_test_recon_path = os.path.join(
    "explainability", "reconstruction_error",
    f"reconstruction_error_table_{config.MODEL_VERSION}_test.parquet",
)
_test_scores_path = os.path.join(
    "isolation_forests", f"iforest_model_{config.MODEL_VERSION}", "test_anomaly_scores.npy"
)

if not os.path.exists(_test_recon_path):
    print(f"Test reconstruction table not found: {_test_recon_path}")
    print("Run Reconstruction_Error_Explainer.ipynb on the test stream first, then re-run this cell.")
else:
    # Load test reconstruction errors and anomaly scores
    test_recon_table = pd.read_parquet(_test_recon_path)
    test_anomaly_scores = np.load(_test_scores_path)

    # Load test stream for z-score and rolling delta context
    _test_v6 = os.path.join("processed_datasets", f"ueba_dataset_{config.MODEL_VERSION}",
                             f"ueba_dataset_{config.MODEL_VERSION}_test_stream.csv")
    _test_v5 = os.path.join("processed_datasets", "ueba_dataset_5", "ueba_dataset_5_test_stream.csv")
    test_ueba = pd.read_csv(_test_v6 if os.path.exists(_test_v6) else _test_v5, index_col=0)
    test_ueba["day"] = pd.to_datetime(test_ueba["day"]).dt.normalize()
    test_ueba["user"] = test_ueba["user"].str.strip().str.lower()

    # Match the training-path gate: exclude pre-baseline rows so the merge with
    # test_anomaly_scores (which was scored only on baseline_complete rows) aligns.
    test_ueba = test_ueba[test_ueba["baseline_complete"]].reset_index(drop=True)

    zscore_cols = [c for c in test_ueba.columns if c.endswith("_zscore")]
    delta_cols  = [c for c in test_ueba.columns if c.endswith("_rolling_delta")]
    test_score_table = test_ueba[["user", "day"] + zscore_cols + delta_cols].copy()
    test_score_table["if_anomaly_score"] = test_anomaly_scores

    test_aggregated = test_recon_table.merge(test_score_table, on=["user", "day"], how="inner")
    assert len(test_aggregated) == len(test_recon_table) == len(test_score_table), \
        "Test recon table and test anomaly-score table must align after the baseline_complete filter"

    # Build test alert table using the same calibrated builder from the train run
    test_alert_df = builder.build_alert_df(test_aggregated, w1=0.5, w2=0.5)
    save_table(df=test_alert_df, save_path=TEST_SAVE_PATH)
    print(f"Test alert table: {len(test_alert_df):,} rows")
    print(test_alert_df["ae_risk_band"].value_counts().to_string())
# Out:
# Test reconstruction table not found: explainability\reconstruction_error\reconstruction_error_table_6_test.parquet
# Run Reconstruction_Error_Explainer.ipynb on the test stream first, then re-run this cell.

# %% [markdown]
# ### Building Calibration-Period Alert Table:
# Scores the held-out calibration eval slice (`ueba_dataset_6_calibration_eval.parquet`) through
# the same AE + IF pipeline and builds alerts using the calibrated `builder` from the train run
# above. Produces `alert_table_6_calib.parquet` — loaded alongside the train alert table by the
# dashboard to close the time gap between the train and test periods.

# %%
from scripts.ReconstructionErrorExplainer import ReconstructionErrorExplainer

CALIB_SAVE_PATH     = os.path.join(f"alert_table_{config.MODEL_VERSION}", f"alert_table_{config.MODEL_VERSION}_calib.parquet")
CALIB_AGG_CASE_PATH = os.path.join(f"alert_table_{config.MODEL_VERSION}", f"cases_{config.MODEL_VERSION}_calib.parquet")

# Load calibration eval slice (insiders retained — full scored population for this period)
calib_eval_df = pd.read_parquet(UEBA_CALIB_EVAL_PATH)
calib_eval_df["day"]  = pd.to_datetime(calib_eval_df["day"]).dt.normalize()
calib_eval_df["user"] = calib_eval_df["user"].str.strip().str.lower()

# Baseline_complete gate: exclude cold-start users (mirrors train section)
calib_eval_df = calib_eval_df[calib_eval_df["baseline_complete"]].reset_index(drop=True)
print(f"Calibration eval rows after baseline_complete gate: {len(calib_eval_df):,}")

# Feature extraction via to_model_matrix — drops all NON_FEATURE_COLS consistently with training
x_calib_eval, calib_feature_cols = to_model_matrix(calib_eval_df)
x_calib_eval_scaled = scaler.transform(x_calib_eval)

# Build reconstruction error + contribution table
calib_explainer = ReconstructionErrorExplainer(feature_names=calib_feature_cols)
calib_recon_table = calib_explainer.explain_to_df(
    x_calib_eval_scaled,
    ae_model,
    metadata=calib_eval_df[["user", "day"]],
    include_feat_err=False,
    include_contributions=True,
)
print(f"Calibration recon table: {calib_recon_table.shape}")

# Compute IF anomaly scores for calibration period
calib_eval_embeddings = enc_model.predict(x_calib_eval_scaled, batch_size=4096)
calib_eval_if_scores  = iforest.anomaly_score(calib_eval_embeddings)

# Build score table with z-score / rolling-delta context for explanation text
zscore_cols_c = [c for c in calib_eval_df.columns if c.endswith("_zscore")]
delta_cols_c  = [c for c in calib_eval_df.columns if c.endswith("_rolling_delta")]
calib_score_table = calib_eval_df[["user", "day"] + zscore_cols_c + delta_cols_c].copy()
calib_score_table["if_anomaly_score"] = calib_eval_if_scores

# Inner-join on (user, day) — same alignment assertion as train section
calib_aggregated = calib_recon_table.merge(calib_score_table, on=["user", "day"], how="inner")
assert len(calib_aggregated) == len(calib_recon_table) == len(calib_score_table), (
    "Calibration recon and score tables must align after the baseline_complete filter. "
    f"Got: recon={len(calib_recon_table)}, score={len(calib_score_table)}, merged={len(calib_aggregated)}"
)

# Build alert table using the same calibrated builder (thresholds + baselines from train run)
calib_alert_df = builder.build_alert_df(calib_aggregated, w1=0.5, w2=0.5)
save_table(df=calib_alert_df, save_path=CALIB_SAVE_PATH)
print(f"Calibration alert table: {len(calib_alert_df):,} rows")
print(calib_alert_df["ae_risk_band"].value_counts().to_string())

# Aggregate into cases
calib_cases_df = builder.aggregate_alerts(calib_alert_df, window_days=5, min_risk="HIGH")
save_table(calib_cases_df, CALIB_AGG_CASE_PATH)
print(f"Calibration cases: {len(calib_cases_df):,}")
# Out:
# Calibration eval rows after baseline_complete gate: 135,458
# Calibration recon table: (135458, 407)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Successfully saved to: explainability\alert_table\alert_table_6\alert_table_6_calib.parquet
# Calibration alert table: 135,458 rows
# ae_risk_band
# LOW         128659
# MEDIUM        5437
# CRITICAL       682
# HIGH           680
# Successfully saved to: explainability\alert_table\alert_table_6\cases_6_calib.parquet
# Calibration cases: 3,255
