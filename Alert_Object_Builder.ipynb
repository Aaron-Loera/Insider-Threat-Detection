# %% [markdown]
# # Creating Alerts with Reconstruction Errors and Anomaly Scores:

# %% [markdown]
# ### Imports & Constants:

# %%
import os
import numpy as np
import pandas as pd
from scripts.AlertObjectBuilder import *

# %%
RECON_TABLE_PATH = r"explainability\reconstruction_error\reconstruction_error_table_4.csv"
UEBA_PATH = r"processed_datasets\ueba_dataset_4\ueba_dataset_4_train.csv"
SCORES_PATH = r"isolation_forests\iforest_model_4\anomaly_scores.npy"
SAVE_PATH = "alert_table_5_test.csv"

# %% [markdown]
# ### Loading Reconstruction Error and Anomaly Score Data:

# %%
# Loading reconstruction table
reconstruction_error_table = pd.read_csv(RECON_TABLE_PATH)

# %%
# Loading anomaly scores
ueba_dataset = pd.read_csv(UEBA_PATH, index_col=0)
anomaly_scores = np.load(SCORES_PATH)

# Adding metadata header to anomaly scores
anomaly_score_table = ueba_dataset[["user", "day"]].copy()
anomaly_score_table["if_anomaly_score"] = anomaly_scores

# %%
# Joining reconstruction errors and anomaly scores
aggregated_table = reconstruction_error_table.merge(anomaly_score_table, on=["user", "day"], how="left")

# %% [markdown]
# ### Initializing and Creating Alert Table:

# %%
builder = AlertObjectBuilder(top_k=3)

# Ordering errors and scores to assign risk levels and percentiles
builder.fit_ae_baseline(aggregated_table["total_reconstruction_error"].values)
builder.fit_if_baseline(aggregated_table["if_anomaly_score"].values)

# %%
alert_df = builder.build_alert_df(aggregated_table, w1=0.5, w2=0.5)

# %%
alert_df.head()
# Out:
#       user         day  ae_percentile_rank ae_risk_band  \
# 0  ama2808  2010-01-02           66.864497          LOW
# 1  gne1365  2010-01-02           56.238482          LOW
# 2  jwm0484  2010-01-02           84.429779       MEDIUM
# 3  tkm1539  2010-01-02           99.642958     CRITICAL
# 4  akk2125  2010-01-02           43.961426          LOW
#
#                                     top_contributors  if_anomaly_score  \
# 0  [(http_total_requests, 0.1200429024419898), (e...          0.459944
# 1  [(external_comm_activity_flag, 0.2198661964323...          0.457806
# 2  [(http_download_count, 0.4130869025126292), (h...          0.459923
# 3  [(off_hours_files_accessed, 0.6997076380137723...          0.603338
# 4  [(external_comm_activity_flag, 0.2905058423566...          0.452810
#
#    if_percentile_rank if_risk_band  \
# 0           85.916663       MEDIUM
# 1           85.580378       MEDIUM
# 2           85.912875       MEDIUM
# 3           97.306166     CRITICAL
# 4           84.778139       MEDIUM
#
#                                          explanation
# 0  AE deviation at 66.86th percentile (LOW); IF a...
# 1  AE deviation at 56.24th percentile (LOW); IF a...
# 2  AE deviation at 84.43th percentile (MEDIUM); I...
# 3  AE deviation at 99.64th percentile (CRITICAL);...
# 4  AE deviation at 43.96th percentile (LOW); IF a...

# %%
# Saving alert table
save_table(df=alert_df, save_path=SAVE_PATH)
# Out:
# Successfully saved to: explainability\alert_table\alert_table_4.csv
